# %% [markdown]
# # primernotebook

# %% [markdown]
# ## **Este es mi primer notebook y voy a hacer lo siguiente**

# %% [markdown]
# ### una lista **enumerada**
# 1. Primero
# 2. Segundo
# 3. Tercero

# %% [markdown]
# ### una lista **por puntos**
# - Primer punto
# - Segundo punto
# - Tercer punto

# %% [markdown]
# ### Mi primer código

# %%
mi_primera_frase = "Hello word"

# %%
# como cuando lo ejecuto no sale nada, tengo que usar la función print ()
print(mi_primera_frase)
# Out:
# Hello word

# %%
# A ver si así lo entendeís mejor:
numeros = [10,20,30,40,50]

# %%
media = sum(numeros) /len(numeros)

# %%
print(media)
# Out:
# 30.0

# %% [markdown]
# ## **Finalizaremos con una bonita imagen**
# ![Mi imagen](renacuajo.jpg)
